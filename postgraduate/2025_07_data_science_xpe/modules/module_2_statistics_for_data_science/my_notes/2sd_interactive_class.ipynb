# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
df_dado = pd.DataFrame({'lado':[1,2,3,4,5,6],'payback':[6,6,6,6,-10,-12],'probabilidade':[1/6,1/6,1/6,1/6,1/6,1/6]})
df_dado
# Out:
#    lado  payback  probabilidade
# 0     1        6       0.166667
# 1     2        6       0.166667
# 2     3        6       0.166667
# 3     4        6       0.166667
# 4     5      -10       0.166667
# 5     6      -12       0.166667

# %%
# Multiplicando no eixo 1 (colunas) e somando
resultado = (df_dado['probabilidade']*df_dado['payback']).sum()/6
print(resultado)
# Out:
# 0.05555555555555558
