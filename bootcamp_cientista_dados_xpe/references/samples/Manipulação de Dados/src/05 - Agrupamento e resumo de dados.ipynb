# %% [markdown]
# #### Agrupamento e Resumo de Dados
# ***
#
# O agrupamento e resumo de dados são etapas essenciais na análise de dados, permitindo extrair informações úteis e insights valiosos a partir de conjuntos de dados complexos. Essas técnicas nos permitem organizar, resumir e comparar os dados com base em categorias ou critérios específicos.

# %% [markdown]
# #### Importação das Bibliotecas

# %%
import pandas as pd

# %% [markdown]
# #### Coletando Dados de Perfil
# ***

# %%
df = pd.read_csv('../datasets/perfil_clientes.csv', sep=';')
df
# Out:
#       idade            classe_trabalho             escolaridade  anos_estudo  \
# 0        39           Servidor Público    Ensino Médio Completo           13
# 1        50                   Autônomo      Superior Incompleto           13
# 2        38  Funcionário Setor Privado  Ensino Médio Incompleto            9
# 3        53  Funcionário Setor Privado  Ensino Médio Incompleto            7
# 4        28  Funcionário Setor Privado    Ensino Médio Completo           13
# ...     ...                        ...                      ...          ...
# 7994     23  Funcionário Setor Privado    Ensino Médio Completo           10
# 7995     19  Funcionário Setor Privado  Ensino Médio Incompleto            9
# 7996     44                        NaN    Ensino Médio Completo           10
# 7997     20  Funcionário Setor Privado  Ensino Médio Incompleto            9
# 7998     41  Funcionário Setor Privado    Ensino Médio Completo           13
#
#      estado_civil    raca       sexo  UF    região  qtde_filhos  salario
# 0        Solteiro  Branco  Masculino  RO     Norte          2.0     4754
# 1          Casado  Branco  Masculino  AC     Norte          1.0     3923
# 2      Divorciado  Branco  Masculino  AM     Norte          0.0     1100
# 3          Casado   Negro  Masculino  RR     Norte          1.0     1100
# 4          Casado   Negro   Feminino  PA     Norte          0.0     3430
# ...           ...     ...        ...  ..       ...          ...      ...
# 7994       Casado   Negro  Masculino  AL  Nordeste          3.0     2856
# 7995     Solteiro  Branco   Feminino  SE  Nordeste          1.0     1100
# 7996       Casado  Branco  Masculino  BA  Nordeste          0.0     3729
# 7997     Solteiro   Negro  Masculino  MG   Sudeste          0.0     1100
# 7998       Casado  Branco  Masculino  AP     Norte          1.0     2579
#
# [7999 rows x 11 columns]

# %% [markdown]
# #### Método groupby
# ***
# Uma das principais ferramentas utilizadas para agrupar e resumir dados no pandas, uma biblioteca popular do Python para análise de dados, é o método groupby. Esse método permite agrupar os dados com base em uma ou mais colunas, criando grupos que compartilham características comuns. Em seguida, podemos aplicar funções de agregação aos grupos para resumir os dados, como contar, somar, calcular média, máximo, mínimo, entre outros.

# %%
df_agrupado = df.groupby('classe_trabalho').sum()
df_agrupado
# Out:
#                             idade  \
# classe_trabalho
# Aposentado                  19278
# Autônomo                    25039
# Desempregado                  137
# Empresário                  20339
# Estagiário                     19
# Funcionário Público          8943
# Funcionário Setor Privado  195259
# MEI                         12315
# Menor Aprendiz               1445
# Servidor Público            11529
#
#                                                                 escolaridade  \
# classe_trabalho
# Aposentado                 Ensino Médio CompletoEnsino Fundamental Comple...
# Autônomo                   Superior IncompletoEnsino Médio IncompletoEnsi...
# Desempregado               Ensino Médio CompletoEnsino Fundamental Incomp...
# Empresário                 Ensino Médio CompletoEnsino Médio CompletoEnsi...
# Estagiário                                           Ensino Médio Incompleto
# Funcionário Público        Ensino Fundamental CompletoEnsino Médio Comple...
# Funcionário Setor Privado  Ensino Médio IncompletoEnsino Médio Incompleto...
# MEI                        Ensino Médio IncompletoEnsino Médio CompletoEn...
# Menor Aprendiz             Ensino Fundamental CompletoEnsino Médio Incomp...
# Servidor Público           Ensino Médio CompletoSuperior IncompletoEnsino...
#
#                            anos_estudo  \
# classe_trabalho
# Aposentado                        2496
# Autônomo                          5986
# Desempregado                        20
# Empresário                        5406
# Estagiário                           9
# Funcionário Público               2361
# Funcionário Setor Privado        53445
# MEI                               3064
# Menor Aprendiz                     575
# Servidor Público                  3463
#
#                                                                 estado_civil  \
# classe_trabalho
# Aposentado                 CasadoCasadoCasadoSolteiroSeparadoDivorciadoVi...
# Autônomo                   CasadoCasadoSolteiroDivorciadoCasadoCasadoCasa...
# Desempregado                                             CasadoViúvoSolteiro
# Empresário                 CasadoSolteiroCasadoCasadoCasadoSolteiroSoltei...
# Estagiário                                                          Solteiro
# Funcionário Público        CasadoCasadoCasadoDivorciadoSolteiroSolteiroCa...
# Funcionário Setor Privado  DivorciadoCasadoCasadoCasadoUnião EstávelSolte...
# MEI                        DivorciadoCasadoCasadoCasadoCasadoDivorciadoCa...
# Menor Aprendiz             SolteiroSolteiroSolteiroSolteiroSolteiroSoltei...
# Servidor Público           SolteiroCasadoCasadoCasadoCasadoViúvoCasadoCas...
#
#                                                                         raca  \
# classe_trabalho
# Aposentado                 BrancoBrancoBrancoBrancoNegroBrancoBrancoNegro...
# Autônomo                   BrancoBrancoBrancoBrancoBrancoBrancoBrancoBran...
# Desempregado                                               PardoBrancoBranco
# Empresário                 BrancoBrancoBrancoBrancoBrancoBrancoBrancoNegr...
# Estagiário                                                            Branco
# Funcionário Público        NegroBrancoNegroBrancoBrancoNegroBrancoBrancoB...
# Funcionário Setor Privado  BrancoNegroNegroBrancoNegroBrancoBrancoNegroBr...
# MEI                        BrancoBrancoBrancoBrancoBrancoPardoBrancoBranc...
# Menor Aprendiz             BrancoBrancoBrancoBrancoBrancoBrancoBrancoBran...
# Servidor Público           BrancoPardoNegroBrancoBrancoAmareloBrancoBranc...
#
#                                                                         sexo  \
# classe_trabalho
# Aposentado                 MasculinoMasculinoMasculinoMasculinoMasculinoF...
# Autônomo                   MasculinoMasculinoMasculinoFemininoMasculinoMa...
# Desempregado                                      MasculinoFemininoMasculino
# Empresário                 MasculinoMasculinoMasculinoMasculinoMasculinoM...
# Estagiário                                                         Masculino
# Funcionário Público        MasculinoMasculinoMasculinoMasculinoFemininoMa...
# Funcionário Setor Privado  MasculinoMasculinoFemininoFemininoFemininoFemi...
# MEI                        MasculinoMasculinoMasculinoMasculinoMasculinoF...
# Menor Aprendiz             FemininoFemininoMasculinoMasculinoMasculinoMas...
# Servidor Público           MasculinoMasculinoMasculinoMasculinoMasculinoM...
#
#                                                                           UF  \
# classe_trabalho
# Aposentado                 PRMSSPCERSGOMATOPBPESPROAPRSGOBAALSESCPEBADFPI...
# Autônomo                   ACMAMGSPPESERJBASCPAMTACAMMTRNGOPEAMMGMSACPASC...
# Desempregado                                                          ROPBBA
# Empresário                 GORRGOAPALSEROCEBARJRRSESCPIRSCERNRRPBRSCEAMMT...
# Estagiário                                                                DF
# Funcionário Público        RSTORJDFPIRJROPARSAPPIBAPASPSCRNAPSERSAMGORNSE...
# Funcionário Setor Privado  AMRRPAAPTOPICERNPEALSEBAESRJPRSCMSMTACAMPAAPPI...
# MEI                        ROSEMTPIAPROSPGORSDFPESCMSSPMAGODFRSMTESMTDFMA...
# Menor Aprendiz             GOPRSPACPBPRMGDFESESAPBAMSMTACBASCPARRRRSCAMMT...
# Servidor Público           ROPBMASCBAAPCEPEROBASPPRDFRJPRSCBAMTCESEESMSAC...
#
#                                                                       região  \
# classe_trabalho
# Aposentado                 SulCentro-OesteSudesteNordesteSulCentro-OesteN...
# Autônomo                   NorteNordesteSudesteSudesteNordesteNordesteSud...
# Desempregado                                           NorteNordesteNordeste
# Empresário                 Centro-OesteNorteCentro-OesteNorteNordesteNord...
# Estagiário                                                      Centro-Oeste
# Funcionário Público        SulNorteSudesteCentro-OesteNordesteSudesteNort...
# Funcionário Setor Privado  NorteNorteNorteNorteNorteNordesteNordesteNorde...
# MEI                        NorteNordesteCentro-OesteNordesteNorteNorteSud...
# Menor Aprendiz             Centro-OesteSulSudesteNorteNordesteSulSudesteC...
# Servidor Público           NorteNordesteNordesteSulNordesteNorteNordesteN...
#
#                            qtde_filhos   salario
# classe_trabalho
# Aposentado                       646.0   1033500
# Autônomo                        1506.0   1581160
# Desempregado                      11.0         0
# Empresário                      1187.0   5054548
# Estagiário                         2.0      1100
# Funcionário Público              545.0    903206
# Funcionário Setor Privado      12981.0  13266341
# MEI                              682.0   1084767
# Menor Aprendiz                    79.0     97600
# Servidor Público                 762.0   1525387

# %%
agrupamento = ['classe_trabalho','estado_civil','sexo']
df_agrupamento = df.groupby(agrupamento)['salario'].mean().round(2).reset_index()
df_agrupamento
# Out:
#      classe_trabalho   estado_civil       sexo  salario
# 0         Aposentado         Casado   Feminino  3287.14
# 1         Aposentado         Casado  Masculino  3966.74
# 2         Aposentado     Divorciado   Feminino  4233.67
# 3         Aposentado     Divorciado  Masculino  3941.40
# 4         Aposentado       Separado   Feminino  2971.00
# ..               ...            ...        ...      ...
# 84  Servidor Público       Solteiro  Masculino  5154.23
# 85  Servidor Público  União Estável   Feminino  5387.00
# 86  Servidor Público  União Estável  Masculino  4793.33
# 87  Servidor Público          Viúvo   Feminino  3025.67
# 88  Servidor Público          Viúvo  Masculino  8107.00
#
# [89 rows x 4 columns]

# %% [markdown]
# #### Método agg
# ***
# Esse método permite aplicar várias funções de agregação aos grupos definidos pelo groupby. Podemos calcular diferentes métricas para cada grupo ou até mesmo aplicar funções personalizadas.

# %%
# Agrupar os dados por categoria e calcular a soma das vendas em cada categoria
agrupamento = ['classe_trabalho','sexo']
grouped = df.groupby(agrupamento)
df_agrupado = grouped.agg({'salario':['sum','mean']}).round(2)
df_agrupado.columns = ['soma de salario','media de salario']
df_agrupado
# Out:
#                                      soma de salario  media de salario
# classe_trabalho           sexo
# Aposentado                Feminino            354618           3940.20
#                           Masculino           678882           3835.49
# Autônomo                  Feminino            225992           2627.81
#                           Masculino          1355168           2699.54
# Desempregado              Feminino                 0              0.00
#                           Masculino                0              0.00
# Empresário                Feminino           1916900          10088.95
#                           Masculino          3137648          10253.75
# Estagiário                Masculino             1100           1100.00
# Funcionário Público       Feminino            258729           3804.84
#                           Masculino           644477           4354.57
# Funcionário Setor Privado Feminino           4316095           2354.66
#                           Masculino          8950246           2521.91
# MEI                       Feminino            156947           4130.18
#                           Masculino           927820           3914.85
# Menor Aprendiz            Feminino             40348           1152.80
#                           Masculino            57252           1145.04
# Servidor Público          Feminino            487368           4471.27
#                           Masculino          1038019           5463.26

# %%
grouped = df.groupby(agrupamento)
grouped.agg(
    soma_salario = ('salario','sum'),
    media_salario = ('salario','mean'),
    valor_maximo = ('salario','max')
).round(2)
# Out:
#                                      soma_salario  media_salario  valor_maximo
# classe_trabalho           sexo
# Aposentado                Feminino         354618        3940.20          6489
#                           Masculino        678882        3835.49          6449
# Autônomo                  Feminino         225992        2627.81          8635
#                           Masculino       1355168        2699.54         14130
# Desempregado              Feminino              0           0.00             0
#                           Masculino             0           0.00             0
# Empresário                Feminino        1916900       10088.95         19955
#                           Masculino       3137648       10253.75         19994
# Estagiário                Masculino          1100        1100.00          1100
# Funcionário Público       Feminino         258729        3804.84         13625
#                           Masculino        644477        4354.57         15298
# Funcionário Setor Privado Feminino        4316095        2354.66         15410
#                           Masculino       8950246        2521.91         15999
# MEI                       Feminino         156947        4130.18          6702
#                           Masculino        927820        3914.85          6743
# Menor Aprendiz            Feminino          40348        1152.80          2948
#                           Masculino         57252        1145.04          3352
# Servidor Público          Feminino         487368        4471.27         15630
#                           Masculino       1038019        5463.26         15335

# %% [markdown]
# #### Método pivot_table
# ***
# Permite criar uma tabela dinâmica a partir dos dados, onde as linhas representam uma categoria, as colunas representam outra categoria e os valores são agregados com base em uma terceira categoria.

# %%
df.head()
# Out:
#    idade            classe_trabalho             escolaridade  anos_estudo  \
# 0     39           Servidor Público    Ensino Médio Completo           13
# 1     50                   Autônomo      Superior Incompleto           13
# 2     38  Funcionário Setor Privado  Ensino Médio Incompleto            9
# 3     53  Funcionário Setor Privado  Ensino Médio Incompleto            7
# 4     28  Funcionário Setor Privado    Ensino Médio Completo           13
#
#   estado_civil    raca       sexo  UF região  qtde_filhos  salario
# 0     Solteiro  Branco  Masculino  RO  Norte          2.0     4754
# 1       Casado  Branco  Masculino  AC  Norte          1.0     3923
# 2   Divorciado  Branco  Masculino  AM  Norte          0.0     1100
# 3       Casado   Negro  Masculino  RR  Norte          1.0     1100
# 4       Casado   Negro   Feminino  PA  Norte          0.0     3430

# %%
df.pivot_table(
    index='sexo',
    columns='região',
    values='anos_estudo',
    aggfunc='mean'
    ).round(2)
# Out:
# região     Centro-Oeste  Nordeste  Norte  Sudeste    Sul
# sexo
# Feminino          10.06     10.01  10.03     9.98  10.03
# Masculino         10.03     10.15  10.08    10.03  10.09

# %% [markdown]
# #### Método info
# ***
# Fornece um resumo conciso das informações básicas sobre um DataFrame, incluindo o número de linhas, o número de colunas, os nomes das colunas e os tipos de dados de cada coluna. Além disso, ele também mostra a quantidade de memória usada pelo DataFrame. Isso é particularmente útil quando estamos lidando com conjuntos de dados grandes e queremos ter uma visão geral rápida de sua estrutura.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   idade            7999 non-null   int64
#  1   classe_trabalho  7612 non-null   object
#  2   escolaridade     7999 non-null   object
#  3   anos_estudo      7999 non-null   int64
#  4   estado_civil     7999 non-null   object
#  5   raca             7999 non-null   object
#  6   sexo             7999 non-null   object
#  7   UF               7999 non-null   object
#  8   região           7999 non-null   object
#  9   qtde_filhos      7997 non-null   float64
#  10  salario          7999 non-null   int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 687.5+ KB

# %% [markdown]
# #### Método describe
#
# ***
# Fornece um resumo estatístico das colunas numéricas de um DataFrame. Ele calcula várias estatísticas descritivas, como contagem, média, desvio padrão, valor mínimo, quartis e valor máximo. Essa função nos ajuda a ter uma visão rápida das principais informações estatísticas de cada coluna numérica, permitindo identificar tendências, distribuições e possíveis outliers nos dados.

# %%
df.describe()
# Out:
#              idade  anos_estudo  qtde_filhos       salario
# count  7999.000000  7999.000000  7997.000000   7999.000000
# mean     38.477060    10.067633     2.404902   3169.312664
# std      13.568667     2.537797     1.704059   3055.862493
# min      17.000000     1.000000     0.000000      0.000000
# 25%      28.000000     9.000000     1.000000   1100.000000
# 50%      37.000000    10.000000     2.000000   2410.000000
# 75%      47.000000    12.000000     4.000000   3640.500000
# max      90.000000    16.000000     5.000000  19994.000000

# %%
df.describe().round(2)
# Out:
#          idade  anos_estudo  qtde_filhos   salario
# count  7999.00      7999.00       7997.0   7999.00
# mean     38.48        10.07          2.4   3169.31
# std      13.57         2.54          1.7   3055.86
# min      17.00         1.00          0.0      0.00
# 25%      28.00         9.00          1.0   1100.00
# 50%      37.00        10.00          2.0   2410.00
# 75%      47.00        12.00          4.0   3640.50
# max      90.00        16.00          5.0  19994.00

# %% [markdown]
# ### Método Transpose
#
# ***
# A função transpose pode ser útil em diversas situações, como quando queremos realizar operações em colunas específicas, quando precisamos ajustar a estrutura do DataFrame para uma determinada análise ou quando desejamos apresentar os dados de uma forma mais adequada para visualização.
#
# A função transpose do Pandas nos permite realizar a transposição de um DataFrame, trocando as linhas pelas colunas e as colunas pelas linhas. Essa função é útil quando queremos modificar a orientação dos dados para melhor adequá-los às nossas necessidades de análise e visualização.

# %%
df.transpose()
# Out:
#                                   0                    1     \
# idade                               39                   50
# classe_trabalho       Servidor Público             Autônomo
# escolaridade     Ensino Médio Completo  Superior Incompleto
# anos_estudo                         13                   13
# estado_civil                  Solteiro               Casado
# raca                            Branco               Branco
# sexo                         Masculino            Masculino
# UF                                  RO                   AC
# região                           Norte                Norte
# qtde_filhos                        2.0                  1.0
# salario                           4754                 3923
#
#                                       2                          3     \
# idade                                   38                         53
# classe_trabalho  Funcionário Setor Privado  Funcionário Setor Privado
# escolaridade       Ensino Médio Incompleto    Ensino Médio Incompleto
# anos_estudo                              9                          7
# estado_civil                    Divorciado                     Casado
# raca                                Branco                      Negro
# sexo                             Masculino                  Masculino
# UF                                      AM                         RR
# região                               Norte                      Norte
# qtde_filhos                            0.0                        1.0
# salario                               1100                       1100
#
#                                       4                          5     \
# idade                                   28                         37
# classe_trabalho  Funcionário Setor Privado  Funcionário Setor Privado
# escolaridade         Ensino Médio Completo                   Mestrado
# anos_estudo                             13                         14
# estado_civil                        Casado                     Casado
# raca                                 Negro                     Branco
# sexo                              Feminino                   Feminino
# UF                                      PA                         AP
# região                               Norte                      Norte
# qtde_filhos                            0.0                        1.0
# salario                               3430                      10787
#
#                                         6                        7     \
# idade                                     49                       52
# classe_trabalho    Funcionário Setor Privado                 Autônomo
# escolaridade     Ensino Fundamental Completo  Ensino Médio Incompleto
# anos_estudo                                5                        9
# estado_civil                   União Estável                   Casado
# raca                                   Negro                   Branco
# sexo                                Feminino                Masculino
# UF                                        TO                       MA
# região                                 Norte                 Nordeste
# qtde_filhos                              1.0                      4.0
# salario                                 1100                     1100
#
#                                       8                          9     ...  \
# idade                                   31                         42  ...
# classe_trabalho  Funcionário Setor Privado  Funcionário Setor Privado  ...
# escolaridade                      Mestrado      Ensino Médio Completo  ...
# anos_estudo                             14                         13  ...
# estado_civil                      Solteiro                     Casado  ...
# raca                                Branco                     Branco  ...
# sexo                              Feminino                  Masculino  ...
# UF                                      PI                         CE  ...
# região                            Nordeste                   Nordeste  ...
# qtde_filhos                            4.0                        5.0  ...
# salario                               6031                       3798  ...
#
#                                       7989                       7990  \
# idade                                   33                         45
# classe_trabalho  Funcionário Setor Privado  Funcionário Setor Privado
# escolaridade                      Mestrado      Ensino Médio Completo
# anos_estudo                             14                         10
# estado_civil                        Casado                 Divorciado
# raca                                Branco                     Branco
# sexo                             Masculino                   Feminino
# UF                                      PI                         CE
# região                            Nordeste                   Nordeste
# qtde_filhos                            5.0                        2.0
# salario                               6063                       3208
#
#                                   7991                     7992  \
# idade                               66                       35
# classe_trabalho             Aposentado                 Autônomo
# escolaridade     Ensino Médio Completo  Ensino Médio Incompleto
# anos_estudo                         10                        9
# estado_civil                    Casado                 Solteiro
# raca                            Branco                    Negro
# sexo                         Masculino                 Feminino
# UF                                  RN                       PB
# região                        Nordeste                 Nordeste
# qtde_filhos                        0.0                      5.0
# salario                           4178                     1100
#
#                                       7993                       7994  \
# idade                                   32                         23
# classe_trabalho  Funcionário Setor Privado  Funcionário Setor Privado
# escolaridade       Ensino Médio Incompleto      Ensino Médio Completo
# anos_estudo                              7                         10
# estado_civil                        Casado                     Casado
# raca                                Branco                      Negro
# sexo                             Masculino                  Masculino
# UF                                      PE                         AL
# região                            Nordeste                   Nordeste
# qtde_filhos                            4.0                        3.0
# salario                               1100                       2856
#
#                                       7995                   7996  \
# idade                                   19                     44
# classe_trabalho  Funcionário Setor Privado                    NaN
# escolaridade       Ensino Médio Incompleto  Ensino Médio Completo
# anos_estudo                              9                     10
# estado_civil                      Solteiro                 Casado
# raca                                Branco                 Branco
# sexo                              Feminino              Masculino
# UF                                      SE                     BA
# região                            Nordeste               Nordeste
# qtde_filhos                            1.0                    0.0
# salario                               1100                   3729
#
#                                       7997                       7998
# idade                                   20                         41
# classe_trabalho  Funcionário Setor Privado  Funcionário Setor Privado
# escolaridade       Ensino Médio Incompleto      Ensino Médio Completo
# anos_estudo                              9                         13
# estado_civil                      Solteiro                     Casado
# raca                                 Negro                     Branco
# sexo                             Masculino                  Masculino
# UF                                      MG                         AP
# região                             Sudeste                      Norte
# qtde_filhos                            0.0                        1.0
# salario                               1100                       2579
#
# [11 rows x 7999 columns]
